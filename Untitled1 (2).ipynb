# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score , mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
df=pd.read_csv('/content/physiolgy1data.csv')
print(df.head(5))
# Out:
#                      Timestamp PERSONAL INFORMATION:\n1: Age   Gender  \
# 0  2023/05/27 5:50:38 pm GMT+5                          15-20  Female
# 1  2023/05/27 5:51:47 pm GMT+5                          20-25  Female
# 2  2023/05/27 5:55:00 pm GMT+5                          15-20    Male
# 3  2023/05/27 5:58:22 pm GMT+5                          15-20  Female
# 4  2023/05/27 6:00:50 pm GMT+5                          15-20    Male
#
#   3: Number of estimated hours you have to sit and work:   \
# 0                                  5-7 hours per day
# 1                                 7-10 hours per day
# 2                                  5-7 hours per day
# 3                                 7-10 hours per day
# 4                                 7-10 hours per day
#
#   PHYSIOLOGICAL ISSUES:\n1: Do you feel pain in the following upper limb  areas during or after work:   \
# 0                                               Neck
# 1                                               Back
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                              --------------  -----
#  0   Timestamp                                                                                                                                                                                                           108 non-null    object
#  1   PERSONAL INFORMATION:
# ...

# %%
df
# Out:
#                         Timestamp PERSONAL INFORMATION:\n1: Age   Gender  \
# 0     2023/05/27 5:50:38 pm GMT+5                          15-20  Female
# 1     2023/05/27 5:51:47 pm GMT+5                          20-25  Female
# 2     2023/05/27 5:55:00 pm GMT+5                          15-20    Male
# 3     2023/05/27 5:58:22 pm GMT+5                          15-20  Female
# 4     2023/05/27 6:00:50 pm GMT+5                          15-20    Male
# ..                            ...                            ...     ...
# 103  2023/06/02 10:45:16 am GMT+5                            40+    Male
# 104   2023/06/03 2:35:00 pm GMT+5                            40+  Female
# 105   2023/06/03 2:37:10 pm GMT+5                          35-40  Female
# 106   2023/06/03 2:38:50 pm GMT+5                          15-20  Female
# 107   2023/06/03 2:40:15 pm GMT+5                            40+  Female
#
#     3: Number of estimated hours you have to sit and work:   \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Columns to encode

# Apply the encoder to each column
enco_col = ['ADDITIONAL CONCERNS:','AWARENESS AND EDUCATION:',' Do you take regular breaks or use ergonomic tools to alleviate the strain on your body?','Do you consciously try to maintain proper posture throughout the day?','POSTURE AND ERGONOMIC','Have you ever experienced any issues with numbness,tingling or pain in the following areas:',' Have you ever experienced any issues with numbness,tingling or pain in the following areas:','PHYSIOLOGICAL ISSUES:',' Number of estimated hours you have to sit and work: ','Gender']
for col in enco_col:
    df[col] = encoder.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ADDITIONAL CONCERNS:'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b1b585f06c42> in <cell line: 10>()
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the dataset
df = pd.read_csv('/content/physiolgy1data.csv')

# Display the first 5 rows and info of the DataFrame
print(df.head(5))
df.info()

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# List of columns to encode (remove any extra spaces in column names)
enco_col = ['ADDITIONAL CONCERNS:',
            'AWARENESS AND EDUCATION:',
            'Do you take regular breaks or use ergonomic tools to alleviate the strain on your body?',
            'Do you consciously try to maintain proper posture throughout the day?',
            'POSTURE AND ERGONOMIC',
            'Have you ever experienced any issues with numbness,tingling or pain in the following areas:',
            'PHYSIOLOGICAL ISSUES:',
            'Number of estimated hours you have to sit and work:',
            'Gender']

# Apply the encoder to each column
for col in enco_col:
    df[col] = encoder.fit_transform(df[col])

# Check the transformed DataFrame
print(df.head())
# Out:
#                      Timestamp PERSONAL INFORMATION:\n1: Age   Gender  \
# 0  2023/05/27 5:50:38 pm GMT+5                          15-20  Female
# 1  2023/05/27 5:51:47 pm GMT+5                          20-25  Female
# 2  2023/05/27 5:55:00 pm GMT+5                          15-20    Male
# 3  2023/05/27 5:58:22 pm GMT+5                          15-20  Female
# 4  2023/05/27 6:00:50 pm GMT+5                          15-20    Male
#
#   3: Number of estimated hours you have to sit and work:   \
# 0                                  5-7 hours per day
# 1                                 7-10 hours per day
# 2                                  5-7 hours per day
# 3                                 7-10 hours per day
# 4                                 7-10 hours per day
#
#   PHYSIOLOGICAL ISSUES:\n1: Do you feel pain in the following upper limb  areas during or after work:   \
# 0                                               Neck
# 1                                               Back
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Load data
df = pd.read_csv('/content/physiolgy1data.csv')

# Clean column names
df.columns = df.columns.str.strip()

# Handle missing values before encoding
imputer = SimpleImputer(strategy='most_frequent')
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Label encoding
encoder = LabelEncoder()
enco_col = ['ADDITIONAL CONCERNS:', 'AWARENESS AND EDUCATION:',
            'Do you take regular breaks or use ergonomic tools to alleviate the strain on your body?',
            'Do you consciously try to maintain proper posture throughout the day?',
            'POSTURE AND ERGONOMIC', 'Have you ever experienced any issues with numbness,tingling or pain in the following areas:',
            'PHYSIOLOGICAL ISSUES:', 'Number of estimated hours you have to sit and work:', 'Gender']

# Apply label encoding to each column
for col in enco_col:
    df[col] = encoder.fit_transform(df[col])

print(df.head())
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ADDITIONAL CONCERNS:'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-e4edf35b3bed> in <cell line: 24>()
#      23 # Apply label encoding to each column
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Load data
df = pd.read_csv('/content/physiolgy1data.csv')

# Clean column names by removing leading/trailing spaces
df.columns = df.columns.str.strip()

# Handle missing values before encoding
imputer = SimpleImputer(strategy='most_frequent')
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Label encoding
encoder = LabelEncoder()
enco_col = ['ADDITIONAL CONCERNS:', 'AWARENESS AND EDUCATION:',
            'Do you take regular breaks or use ergonomic tools to alleviate the strain on your body?',
            'Do you consciously try to maintain proper posture throughout the day?',
            'POSTURE AND ERGONOMIC', 'Have you ever experienced any issues with numbness,tingling or pain in the following areas:',
            'PHYSIOLOGICAL ISSUES:', 'Number of estimated hours you have to sit and work:', 'Gender']

# Apply label encoding to each column
for col in enco_col:
    df[col] = encoder.fit_transform(df[col])

print(df.head())
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ADDITIONAL CONCERNS:'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-739e170adf98> in <cell line: 24>()
#      23 # Apply label encoding to each column
# ...
